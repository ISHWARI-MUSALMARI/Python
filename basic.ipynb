# %%
#markdown 
# it is used for headings
##### it is used to increase font size
# as many times you will use ## the font size will increase

# %% [markdown]
# ## INTRODUCTION

# %%
# raw 
# brief introduction about your project

# %%
""" multi-line comments"""
# Out:
# ' multi-line comments'

# %%
# identifiers
# it should not begin with numbers
#it should not have any special character
# it should be a keyword

# %%
a=2
b=2
a+b
# Out:
# 4

# %%
# data types
#numerical
#categorical

# %%
age =21 #integer

# %%
age
# Out:
# 21

# %%
cgpa =9.1 #float/decimal value

# %%
cgpa
# Out:
# 9.1

# %%
name="ishmb" #string

# %%
name
# Out:
# 'ishmb'

# %%
Trainer = True #boolean/bool

# %%
Trainer
# Out:
# True

# %% [markdown]
# #### ISHWARI

# %%
# Indexing

# %%
name ="Ishwari"

# %%
name[0]
# Out:
# 'I'

# %%
name[6]
# Out:
# 'i'

# %%
#Slicing

# %%
greet ="hello good morning"

# %%
greet
# Out:
# 'hello good morning'

# %%
greet[0:5]
# Out:
# 'hello'

# %%
greet[11:]
# Out:
# 'morning'

# %%
greet[10:18]
# Out:
# ' morning'

# %%
greet[:5]
# Out:
# 'hello'

# %%
greet
# Out:
# 'hello good morning'

# %%
greet.startswith("H")
# Out:
# False

# %%
greet.startswith("h")
# Out:
# True

# %%
greet.endswith("g")
# Out:
# True

# %%
#Typecasting
#Converting one datatypes into another

# %%
age=29
cgpa=9.12
name="ish"
Trainer=True

# %%
age
# Out:
# 29

# %%
name
# Out:
# 'ish'

# %%
float(age)
# Out:
# 29.0

# %%
str(age)
# Out:
# '29'
